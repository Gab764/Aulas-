# %% [markdown]
# # Jogo da Forca

# %% [markdown]
# #### Gabriela Santos Almeida da Silva *SP3166333*

# %% [markdown]
# # import random #Importando bibliotecas e funções que será utilizadas;
# from time import sleep
#
# def palavraAleatoria():  # Função que traz uma palavra aleatória do banco de dados;
#      with open('Portuguese.txt', 'r+') as f: # Abrir arquivo .txt com banco de dados como f
#         contents = list(f.readlines())  # Ler linha por ninha do arquivo e coloca-los dentro de contents
#         palavra = random.choice(contents) # Escolher uma palavra aleatória do contents e coloca-la em palavra
#         palavra = palavra.strip() # Jogar palavra escolida
#
# def rodarjogo(): # Função para rodar jogo
#     palavraQueDeveSerAdivinhada =palavraAleatoria()
#
#     palavraQueDeveSerAdivinhadaTracos = {} # Lista de palavras que deve ser advinhada
#     palavrasErradas = ["",]
#     counterLetra = 0
#     counterErro = 0
#     outputDoBoneco = [" |______ \n |      | \n |\n |\n |" , " |______ \n |      | \n |      O \n |\n |\n | " , " |______ \n |      | \n |      O \n |      I \n |\n |\n | ", " |______ \n |      | \n |      O \n |      I /\n |\n |\n | "," |______ \n |      | \n |      O \n |    \ I /\n |\n |\n | "," |______ \n |      | \n |      O \n |    \ I /\n |     /\n |\n | "," |______ \n |      | \n |      O \n |    \ I /\n |     / \ \n |\n | "]
#     # O desenho do boneco nas condições de nenhuma letra errada
#
#
#     #Criação do dicionario
#     for letra in palavraQueDeveSerAdivinhada:
#         if palavraQueDeveSerAdivinhadaTracos.get(letra) == None: #
#             palavraQueDeveSerAdivinhadaTracos[letra] = "_ "
#         else:
#             palavraQueDeveSerAdivinhadaTracos[letra+str(counterLetra)] = "_ "
#             counterLetra += 1
#             continue
#
#
# # Limites de chances até o jogo acabar
#     while counterErro < 7:
#         if not "_ " in palavraQueDeveSerAdivinhadaTracos.values():
#             break
#         #Imagem inicial no terminal
#         print("FORCA DO ZEUS")
#         print("")
#         print(outputDoBoneco[counterErro])
#
#         #Output para o terminal
#         for letra in palavrasErradas:
#             print(letra,end="")
#
#         print("")
#         for i in palavraQueDeveSerAdivinhadaTracos:
#             print(palavraQueDeveSerAdivinhadaTracos[i],end="")
#         print("")
#         print("Descubra a palavra")
#
#         while True:
#             palavraChutada = input("Digite uma letra: ")
#             if palavraChutada.isdigit():
#                 print("POR FAVOR, DIGITE UMA LETRA")
#             elif len(palavraChutada) > 1 :
#                 print("POR FAVOR, APENAS UMA LETRA")
#             elif palavraChutada == "":
#                 print("VOCÊ PRECISA DIGITAR ALGO")
#             elif palavraChutada in palavrasErradas:
#                 print("VOCÊ JÁ DIGITOU ESSA LETRA. ESCOLHA OUTRA")
#             else:
#                 break
#
#         palavraChutada =str(palavraChutada)
#
#         #Condição para se o usuario acertou ou não
#         if palavraChutada in palavraQueDeveSerAdivinhadaTracos.keys():
#             print("Parabéns, você acertou!")
#             for i in palavraQueDeveSerAdivinhadaTracos:
#                 if palavraChutada in i:
#                     palavraQueDeveSerAdivinhadaTracos[i] = palavraChutada
#         else:
#             print("Você errou :(")
#             palavrasErradas.append(palavraChutada)
#             counterErro += 1
#     # Mensagem final do jogo dependendo do acerto do usuário ou não
#     print("="*100)
#     print("PARABÉNS POR JOGAR NOSSO JOGO, FICAMOS MUITO FELIZ POR TER VOCÊ JOGADO ELE.")
#     print("Desenvolvido por: Davi Brum, Gabriela Almeida, Guilherme Almeida")
#     print("="*100)
#
#     print("="*100)
#     print("A PALAVRA ERA {}".format(palavraQueDeveSerAdivinhada))
#     print("====================================================================================================")
#     print("====================================================================================================")
#
#     if counterErro < 7:
#      print("VOCÊ VENCEU. Pelo visto você é bom mesmo em!")
#     else:
#         print("Infelizmente você perdeu, mas não fique desesperado, você pode tentar outra vez!")
#     print("="*100)
#
#     choice = int(input("Deseja jogar mais uma vez? \n SIM[0]\n NÃO[1]\n Resposta: "))
#     if choice == 0:
#         return True
#     elif choice == 1:
#         return False
#     else:
#         print("COMO VOCÊ OUSA COLOCAR ALGO DIFERENTE DE SIM OU NÃO ? Ira jogar novamente >:D")
#         return True
# # Escolha de voltar a jogar ou parar
# print("Seja bem vindo ao Forca de Zeus!")
#
# while True:
#     while True:
#         try:
#             escolhaJogador = int(input("gostaria de começar ? \n [0]SIM \n [1]NÃO \n sua escolha:"))
#             break
#         except:
#             print("Apenas número, por favor")
#
#     if escolhaJogador == 0:
#         print("Ficamos muito feliz que você queira jogar nosso jogo...")
#         sleep(3)
#     else:
#         print("Que pena que você não escolheu jogar por pura vontade. Vamos pro jogo!")
#         sleep(3)
#     break
# rodarOJogo = True
# while rodarOJogo == True:
#     rodarOJogo = rodarjogo()
#
# print("Volte sempre!")
